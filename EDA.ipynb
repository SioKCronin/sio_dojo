# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("test.csv")

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Data1     Data2     Data3     Data4     Data5     Data6     Data7  \
# 0  0.882032  0.436207  0.629117  0.518911  0.906503  0.672300  0.777902
# 1  0.385652  0.440777  0.393894  0.177767  0.719416  0.985917  0.830585
# 2  0.096295  0.869501  0.496932  0.649575  0.777231  0.117377  0.318072
#
#       Data8
# 0  0.112367
# 1  0.763047
# 2  0.060324

# %%
df.plot()
plt.show()

# %%
df['Data1'].describe()
# Out:
# count    3.000000
# mean     0.454660
# std      0.397388
# min      0.096295
# 25%      0.240974
# 50%      0.385652
# 75%      0.633842
# max      0.882032
# Name: Data1, dtype: float64

# %%
df['Data1'].plot()
plt.show()
